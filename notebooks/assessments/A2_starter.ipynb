# %% [markdown]
# # NUTDTS 816 · Assignment 2: ARIMA and SARIMA modelling (7%)
#
# Due Monday 12 October 2026, 23:59 WAT. Series A: bonny_light or nigeria_fx (monthly). Series B: nigeria_grid. Hold out the last 12 months of each.
#
# **Name / Group:** ______  **Date:** ______
#
# This notebook must run top to bottom from a fresh Colab runtime. Keep the section headings; put your commentary in the markdown cells and your code in the code cells. Finish with the AI-use statement.

# %%
# ---- Setup: run once per Colab session ----
# 1. Install the course libraries (about two minutes the first time)
# !pip install -q statsmodels pmdarima statsforecast neuralforecast lightgbm arch plotly

# 2. Fetch the course data module and data snapshots from the course repository.
#    Replace REPO with your fork or the official course repository URL.
REPO = "https://raw.githubusercontent.com/<your-github-user>/nutdts816/main"
import urllib.request, os
os.makedirs("data", exist_ok=True)
urllib.request.urlretrieve(f"{REPO}/src/tsdata.py", "tsdata.py")
DATA_FILES = ["nigeria_cpi", "nigeria_fx", "nigeria_grid", "nigeria_malaria", "nigeria_rainfall", "bonny_light", "daily_demand",
              "airpassengers", "a10", "h02", "ausbeer", "elecequip", "usmelec", "goog", "nile", "austourists", "oil", "dax", "uschange", "elecdemand"]
for f in DATA_FILES:
    urllib.request.urlretrieve(f"{REPO}/data/{f}.csv", f"data/{f}.csv")

import warnings; warnings.filterwarnings("ignore")
import pandas as pd, numpy as np, matplotlib.pyplot as plt
plt.rcParams.update({"figure.figsize": (9, 3.6), "axes.grid": True, "grid.alpha": 0.3, "axes.spines.top": False, "axes.spines.right": False})
import tsdata
print("Setup complete.")

# %% [markdown]
# ## 1. Stationarity assessment
#
# *plots, ACF/PACF, ADF and KPSS; decide d (and D for Series B)*

# %%
# code

# %% [markdown]
# Commentary:

# %% [markdown]
# ## 2. Candidate models from the correlogram (at least three each)
#
# *state the signature that motivates each*

# %%
# code

# %% [markdown]
# Commentary:

# %% [markdown]
# ## 3. Estimation and comparison table
#
# *AICc, Ljung-Box p, warnings; same d only*

# %%
# code

# %% [markdown]
# Commentary:

# %% [markdown]
# ## 4. Diagnostics of the preferred models
#
# *plot_diagnostics; roots; residual ACF*

# %%
# code

# %% [markdown]
# Commentary:

# %% [markdown]
# ## 5. Automatic selection compared
#
# *pmdarima or statsforecast; explain any disagreement*

# %%
# code

# %% [markdown]
# Commentary:

# %% [markdown]
# ## 6. 12-month forecasts with 80% and 95% intervals
#
# *plot against training data*

# %%
# code

# %% [markdown]
# Commentary:

# %% [markdown]
# ## 7. Hold-out evaluation against naive / seasonal naive
#
# *MAE, RMSE, MASE in one table*

# %%
# code

# %% [markdown]
# Commentary:

# %% [markdown]
# ## 8. Interval coverage and credibility
#
# *fraction inside 80% and 95%; why ARIMA intervals are often too narrow*

# %%
# code

# %% [markdown]
# Commentary:

# %% [markdown]
# ## AI-use statement
#
# (Two to five lines: which tools, for what. 'No AI tools were used' is acceptable.)
